# %%
import pandas as pd
import datetime as dt
import chardet

# %%
with open('test_data_2.csv', 'rb') as f: 
    result = chardet.detect(f.read())

    print(result)
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
df = pd.read_csv("test_data_2.csv", encoding='ISO-8859-1')
                

# Drop columns that won't be used

# Preview the dataset

df_renamed = df.rename(columns={"Table with row headers in column A and column headers in rows 5, 58, 111, 164, 217, 270, 323, 376, 429, 482, 535, 588, 641, 694, 747, 800, 853, 906, 959, 1012, 1065, 1118, 1171, 1224, 1277, 1330, 1383, 1436, 1489, 1542, 1595, 1648, 1701, 1754, 1807, 1860, 1913, 1966, 2019, 2072, 2125, 2178, 2231, 2284, and 2337" : "States"})


df_renamed
# Out:
#                                                  States        Unnamed: 1  \
# 0     Table 19. Number of Poor and Poverty Rate by S...               NaN
# 1     (Population in thousands. Population as of Mar...               NaN
# 2                                                  2022               NaN
# 3                                                 State  Total population
# 4                                               Alabama             4,990
# ...                                                 ...               ...
# 2384                                      West Virginia             1,952
# 2385                                          Wisconsin             4,724
# 2386                                            Wyoming               468
# 2387  Source: U.S. Census Bureau, Current Population...               NaN
# 2388  Footnotes are available at <www.census.gov/top...               NaN
#
#              Unnamed: 2                Unnamed: 3          Unnamed: 4  \
# ...
